# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Supermart Grocery Sales.csv', encoding = 'utf-8')

# %%
df
# Out:
#      Order ID Customer Name           Category      Sub Category         City  \
# 0         OD1        Harish       Oil & Masala           Masalas      Vellore
# 1         OD2         Sudha          Beverages     Health Drinks  Krishnagiri
# 2         OD3       Hussain        Food Grains      Atta & Flour   Perambalur
# 3         OD4       Jackson   Fruits & Veggies  Fresh Vegetables   Dharmapuri
# 4         OD5       Ridhesh        Food Grains   Organic Staples         Ooty
# ...       ...           ...                ...               ...          ...
# 9989   OD9990        Sudeep  Eggs, Meat & Fish              Eggs      Madurai
# 9990   OD9991          Alan             Bakery          Biscuits  Kanyakumari
# 9991   OD9992          Ravi        Food Grains              Rice         Bodi
# 9992   OD9993          Peer       Oil & Masala            Spices   Pudukottai
# 9993   OD9994        Ganesh        Food Grains      Atta & Flour  Tirunelveli
#
# ...

# %% [markdown]
# Q1. Which region has the most sales?

# %%
most_sales = df.groupby('Region')['Sales'].sum().sort_values(ascending=False).head(1)
most_sales
# Out:
# Region
# West    4798743
# Name: Sales, dtype: int64

# %% [markdown]
# Answer:
# 'West' region has the most sales. '4798743'

# %% [markdown]
# Q2. Which region has the highest profit?

# %%
highest_profit = df.groupby('Region')['Profit'].sum().sort_values(ascending=False).head(1)
highest_profit
# Out:
# Region
# West    1192004.61
# Name: Profit, dtype: float64

# %% [markdown]
# Answer: 'West' region has the highest profit. '1192004.61'

# %% [markdown]
# Q3. Who is the most frequent customer?

# %%
most_frequent_customer = df['Customer Name'].value_counts().sort_values(ascending=False).head(1)
most_frequent_customer
# Out:
# Customer Name
# Amrish    227
# Name: count, dtype: int64

# %% [markdown]
# Answer: Amrish is the most frequent customer with '227' orders

# %% [markdown]
# Q4. Among the categories."Beverages", 'Bakery' and 'Snacks'.Which is most profitable in south region?

# %%
south_data = df[df['Region'] == 'South']
south_data
# Out:
#      Order ID Customer Name          Category      Sub Category          City  \
# 1         OD2         Sudha         Beverages     Health Drinks   Krishnagiri
# 3         OD4       Jackson  Fruits & Veggies  Fresh Vegetables    Dharmapuri
# 4         OD5       Ridhesh       Food Grains   Organic Staples          Ooty
# 12       OD13        Sharon            Snacks           Cookies      Dindigul
# 43       OD44        Mathew            Snacks           Cookies    Dharmapuri
# ...       ...           ...               ...               ...           ...
# 9937   OD9938         Yusuf  Fruits & Veggies  Fresh Vegetables       Madurai
# 9938   OD9939         Vince            Snacks           Cookies  Virudhunagar
# 9939   OD9940        Adavan            Snacks        Chocolates          Bodi
# 9940   OD9941           Anu         Beverages       Soft Drinks   Kanyakumari
# 9941   OD9942        Amrish            Snacks           Cookies    Pudukottai
#
# ...

# %%
filtered_data = south_data[south_data['Category'].isin(['Beverages', 'Bakery', 'Snacks'])]
filtered_data
# Out:
#      Order ID Customer Name   Category   Sub Category          City  \
# 1         OD2         Sudha  Beverages  Health Drinks   Krishnagiri
# 12       OD13        Sharon     Snacks        Cookies      Dindigul
# 43       OD44        Mathew     Snacks        Cookies    Dharmapuri
# 72       OD73          Alan     Snacks        Cookies         Theni
# 74       OD75        Arvind  Beverages    Soft Drinks       Vellore
# ...       ...           ...        ...            ...           ...
# 9936   OD9937         Jonas     Bakery       Biscuits  Virudhunagar
# 9938   OD9939         Vince     Snacks        Cookies  Virudhunagar
# 9939   OD9940        Adavan     Snacks     Chocolates          Bodi
# 9940   OD9941           Anu  Beverages    Soft Drinks   Kanyakumari
# 9941   OD9942        Amrish     Snacks        Cookies    Pudukottai
#
#       Order Date Region  Sales  Discount   Profit       State
# 1     11-08-2017  South    749      0.18   149.80  Tamil Nadu
# ...

# %%
most_profitable = filtered_data.groupby('Category')['Profit'].sum().sort_values(ascending=False).head(1)
most_profitable
# Out:
# Category
# Snacks    94979.87
# Name: Profit, dtype: float64

# %% [markdown]
# Answer: 'Snacks' are most profitable in south region with '94979.87' profit.

# %% [markdown]
# Q5. Plot the sales of the store according to order date. Using linear regression, find if sales is increasing or decreasing?

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], errors='coerce', dayfirst=False, infer_datetime_format=True)
df['Order Date']
# Out:
# C:\Users\AL REHMAN LAPTOPS\AppData\Local\Temp\ipykernel_9932\90420307.py:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df['Order Date'] = pd.to_datetime(df['Order Date'], errors='coerce', dayfirst=False, infer_datetime_format=True)
# 0      2017-11-08
# 1      2017-11-08
# 2      2017-06-12
# 3      2016-10-11
# 4      2016-10-11
#           ...
# 9989          NaT
# 9990   2015-07-12
# 9991   2017-06-06
# 9992          NaT
# 9993          NaT
# Name: Order Date, Length: 9994, dtype: datetime64[ns]

# %%
sales_by_date = df.groupby('Order Date')['Sales'].sum().reset_index()
sales_by_date
# Out:
#     Order Date  Sales
# 0   2015-01-03    864
# 1   2015-01-04   3490
# 2   2015-01-05    878
# 3   2015-01-06  14026
# 4   2015-01-07   3216
# ..         ...    ...
# 478 2018-12-07  18205
# 479 2018-12-08  42990
# 480 2018-12-09  48405
# 481 2018-12-10  31842
# 482 2018-12-11  37319
#
# [483 rows x 2 columns]

# %%
df
# Out:
#      Order ID Customer Name           Category      Sub Category         City  \
# 0         OD1        Harish       Oil & Masala           Masalas      Vellore
# 1         OD2         Sudha          Beverages     Health Drinks  Krishnagiri
# 2         OD3       Hussain        Food Grains      Atta & Flour   Perambalur
# 3         OD4       Jackson   Fruits & Veggies  Fresh Vegetables   Dharmapuri
# 4         OD5       Ridhesh        Food Grains   Organic Staples         Ooty
# ...       ...           ...                ...               ...          ...
# 9989   OD9990        Sudeep  Eggs, Meat & Fish              Eggs      Madurai
# 9990   OD9991          Alan             Bakery          Biscuits  Kanyakumari
# 9991   OD9992          Ravi        Food Grains              Rice         Bodi
# 9992   OD9993          Peer       Oil & Masala            Spices   Pudukottai
# 9993   OD9994        Ganesh        Food Grains      Atta & Flour  Tirunelveli
#
# ...

# %%
# !pip3 install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 473.1 kB/s eta 0:00:17
#    -- ------------------------------------- 0.5/8.1 MB 473.1 kB/s eta 0:00:17
#    -- ------------------------------------- 0.5/8.1 MB 473.1 kB/s eta 0:00:17
#    -- ------------------------------------- 0.5/8.1 MB 473.1 kB/s eta 0:00:17
#    --- ------------------------------------ 0.8/8.1 MB 320.5 kB/s eta 0:00:23
#    --- ------------------------------------ 0.8/8.1 MB 320.5 kB/s eta 0:00:23
# ...

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.plot(sales_by_date['Order Date'], sales_by_date['Sales'])
plt.title("Sales Over Time")
plt.xlabel('Order Date')
plt.ylabel('Sales')
plt.show()
