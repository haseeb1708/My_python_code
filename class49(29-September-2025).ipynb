# %%
import numpy as np
import pandas as pd
import random

# ✅ Create dataset with duplicates and nulls already included
data = {
    'Students': [
        'Ali', 'Hassam', 'Kashif', 'Waseem', 'Sattar',
        'Noman', 'Hina', 'Ayesha', 'Bilal', 'Zain',
        'Hassan', 'Sara', 'Hamza', 'Iqra', 'Usman',
        'Fatima', 'Ahmed', 'Tariq', 'Maha', 'Raza',
        # 🔁 Duplicates
        'Ali', 'Hina', 'Sara'
    ],
    'Marks': [
        85, 76, np.nan, 92, 67,
        73, 89, 55, 90, np.nan,
        81, 60, 78, 88, 95,
        70, 82, 79, 91, 66,
        # 🔁 Duplicates
        85, 89, 60
    ],
    'Language': [
        'Python', 'JavaScript', 'TypeScript', 'C', 'C#',
        'Java', np.nan, 'Rust', 'Swift', 'Kotlin',
        'PHP', 'Ruby', 'Perl', 'Scala', 'Dart',
        'SQL', 'R', 'Julia', 'MATLAB', 'Elixir',
        # 🔁 Duplicates
        'Python', np.nan, 'Ruby'
    ],
    'Age': [
        21, 23, 22, 20, 25,
        24, np.nan, 19, 26, 21,
        23, 22, 20, 24, 23,
        21, 25, 26, np.nan, 22,
        # 🔁 Duplicates
        21, np.nan, 22
    ],
    'Gender': [
        'Male', 'Male', 'Male', 'Male', 'Male',
        'Male', 'Female', 'Female', 'Male', 'Male',
        'Male', 'Female', 'Male', 'Female', 'Male',
        'Female', 'Male', 'Male', 'Female', 'Male',
        # 🔁 Duplicates
        'Male', 'Female', 'Female'
    ],
    'City': [
        'Lahore', 'Karachi', np.nan, 'Multan', 'Peshawar',
        'Quetta', 'Rawalpindi', 'Faisalabad', 'Sialkot', 'Hyderabad',
        'Gujranwala', 'Sargodha', 'Bahawalpur', 'Sukkur', 'Mardan',
        'Kasur', 'Okara', 'Dera Ghazi Khan', 'Chiniot', 'Swat',
        # 🔁 Duplicates
        'Lahore', 'Rawalpindi', 'Sargodha'
    ],
    'Country': ['Pakistan'] * 23,
    'Passed': np.random.choice([True, False], 23),
    'Grade': np.random.choice(['A', 'B', 'C', 'D'], 23),
    'Attendance': np.random.randint(70, 100, 23),
    'Project_Score': np.random.randint(60, 100, 23),
    'Assignments': np.random.randint(5, 15, 23),
    'Quizzes': np.random.randint(3, 10, 23),
    'Semester': np.random.choice(['Spring', 'Fall'], 23),
    'GPA': np.round(np.random.uniform(2.0, 4.0, 23), 2),
    'Scholarship': np.random.choice([True, False], 23),
    'Phone': [f"+92-300-{random.randint(1000000, 9999999)}" for _ in range(23)],
    'Email': [
        'student1@example.com', 'student2@example.com', 'student3@example.com', 'student4@example.com', 'student5@example.com',
        'student6@example.com', np.nan, 'student8@example.com', 'student9@example.com', 'student10@example.com',
        'student11@example.com', 'student12@example.com', 'student13@example.com', 'student14@example.com', 'student15@example.com',
        'student16@example.com', 'student17@example.com', 'student18@example.com', 'student19@example.com', 'student20@example.com',
        'student1@example.com', 'student7@example.com', np.nan
    ],
    'Join_Year': np.random.randint(2018, 2025, 23),
    'Graduated': np.random.choice([True, False], 23)
}

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#   Students  Marks    Language   Age Gender      City   Country  Passed Grade  \
# 0      Ali   85.0      Python  21.0   Male    Lahore  Pakistan    True     B
# 1   Hassam   76.0  JavaScript  23.0   Male   Karachi  Pakistan    True     A
# 2   Kashif    NaN  TypeScript  22.0   Male       NaN  Pakistan   False     B
# 3   Waseem   92.0           C  20.0   Male    Multan  Pakistan    True     D
# 4   Sattar   67.0          C#  25.0   Male  Peshawar  Pakistan   False     D
#
#    Attendance  Project_Score  Assignments  Quizzes Semester   GPA  \
# 0          98             68           10        9   Spring  2.96
# 1          89             78            5        3     Fall  2.20
# 2          80             83            5        9     Fall  3.62
# 3          75             83           12        9   Spring  3.44
# 4          89             75            6        3   Spring  3.25
#
#    Scholarship            Phone                 Email  Join_Year  Graduated
# 0        False  +92-300-3759168  student1@example.com       2021      False
# 1         True  +92-300-1887373  student2@example.com       2021      False
# 2        False  +92-300-1988183  student3@example.com       2023       True
# 3         True  +92-300-4587653  student4@example.com       2024      False
# 4         True  +92-300-1584231  student5@example.com       2024      False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Students       23 non-null     object
#  1   Marks          21 non-null     float64
#  2   Language       21 non-null     object
#  3   Age            20 non-null     float64
#  4   Gender         23 non-null     object
#  5   City           22 non-null     object
#  6   Country        23 non-null     object
#  7   Passed         23 non-null     bool
#  8   Grade          23 non-null     object
#  9   Attendance     23 non-null     int32
#  10  Project_Score  23 non-null     int32
#  11  Assignments    23 non-null     int32
#  12  Quizzes        23 non-null     int32
#  13  Semester       23 non-null     object
#  14  GPA            23 non-null     float64
#  15  Scholarship    23 non-null     bool
#  16  Phone          23 non-null     object
#  17  Email          21 non-null     object
#  18  Join_Year      23 non-null     int32
#  19  Graduated      23 non-null     bool
# dtypes: bool(3), float64(3), int32(5), object(9)
# memory usage: 2.8+ KB

# %%
df.index
# Out:
# RangeIndex(start=0, stop=23, step=1)

# %%
df.isnull().sum()
# Out:
# Students         0
# Marks            2
# Language         2
# Age              3
# Gender           0
# City             1
# Country          0
# Passed           0
# Grade            0
# Attendance       0
# Project_Score    0
# Assignments      0
# Quizzes          0
# Semester         0
# GPA              0
# Scholarship      0
# Phone            0
# Email            2
# Join_Year        0
# Graduated        0
# dtype: int64

# %%
df['Marks']
df['Email']
# Out:
# 0      student1@example.com
# 1      student2@example.com
# 2      student3@example.com
# 3      student4@example.com
# 4      student5@example.com
# 5      student6@example.com
# 6                       NaN
# 7      student8@example.com
# 8      student9@example.com
# 9     student10@example.com
# 10    student11@example.com
# 11    student12@example.com
# 12    student13@example.com
# 13    student14@example.com
# 14    student15@example.com
# 15    student16@example.com
# 16    student17@example.com
# 17    student18@example.com
# 18    student19@example.com
# 19    student20@example.com
# 20     student1@example.com
# 21     student7@example.com
# 22                      NaN
# Name: Email, dtype: object

# %%
df.head()
# Out:
#   Students  Marks    Language   Age Gender      City   Country  Passed Grade  \
# 0      Ali   85.0      Python  21.0   Male    Lahore  Pakistan    True     B
# 1   Hassam   76.0  JavaScript  23.0   Male   Karachi  Pakistan    True     A
# 2   Kashif    NaN  TypeScript  22.0   Male       NaN  Pakistan   False     B
# 3   Waseem   92.0           C  20.0   Male    Multan  Pakistan    True     D
# 4   Sattar   67.0          C#  25.0   Male  Peshawar  Pakistan   False     D
#
#    Attendance  Project_Score  Assignments  Quizzes Semester   GPA  \
# 0          98             68           10        9   Spring  2.96
# 1          89             78            5        3     Fall  2.20
# 2          80             83            5        9     Fall  3.62
# 3          75             83           12        9   Spring  3.44
# 4          89             75            6        3   Spring  3.25
#
#    Scholarship            Phone                 Email  Join_Year  Graduated
# 0        False  +92-300-3759168  student1@example.com       2021      False
# 1         True  +92-300-1887373  student2@example.com       2021      False
# 2        False  +92-300-1988183  student3@example.com       2023       True
# 3         True  +92-300-4587653  student4@example.com       2024      False
# 4         True  +92-300-1584231  student5@example.com       2024      False

# %%
len(df.index)
# Out:
# 23

# %%
df.isna().sum()
# Out:
# Students         0
# Marks            2
# Language         2
# Age              3
# Gender           0
# City             1
# Country          0
# Passed           0
# Grade            0
# Attendance       0
# Project_Score    0
# Assignments      0
# Quizzes          0
# Semester         0
# GPA              0
# Scholarship      0
# Phone            0
# Email            2
# Join_Year        0
# Graduated        0
# dtype: int64

# %%
len(df.dropna().index)
# Out:
# 17

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Fill null values in specific column

# %%
df['Age'].fillna(df['Age'].mean(), inplace=True)
# Out:
# C:\Users\AL REHMAN LAPTOPS\AppData\Local\Temp\ipykernel_10560\1698716155.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(), inplace=True)

# %%
df.isna().sum()
# Out:
# Students         0
# Marks            2
# Language         2
# Age              0
# Gender           0
# City             1
# Country          0
# Passed           0
# Grade            0
# Attendance       0
# Project_Score    0
# Assignments      0
# Quizzes          0
# Semester         0
# GPA              0
# Scholarship      0
# Phone            0
# Email            2
# Join_Year        0
# Graduated        0
# dtype: int64

# %%
df['Marks'].value_counts().idxmax
# Out:
# <bound method Series.idxmax of Marks
# 85.0    2
# 89.0    2
# 60.0    2
# 67.0    1
# 73.0    1
# 92.0    1
# 55.0    1
# 90.0    1
# 81.0    1
# 76.0    1
# 78.0    1
# 88.0    1
# 95.0    1
# 70.0    1
# 82.0    1
# 79.0    1
# 91.0    1
# 66.0    1
# Name: count, dtype: int64>

# %%
fill_value = df['Marks'].mode().mean()
df['Marks'].fillna(fill_value, inplace=True)
# Out:
# C:\Users\AL REHMAN LAPTOPS\AppData\Local\Temp\ipykernel_10560\894061404.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Marks'].fillna(fill_value, inplace=True)

# %%
df.isnull().sum()
# Out:
# Students         0
# Marks            0
# Language         2
# Age              0
# Gender           0
# City             1
# Country          0
# Passed           0
# Grade            0
# Attendance       0
# Project_Score    0
# Assignments      0
# Quizzes          0
# Semester         0
# GPA              0
# Scholarship      0
# Phone            0
# Email            2
# Join_Year        0
# Graduated        0
# dtype: int64

# %%
df['Language'].fillna(df['Language'].mode()[0], inplace=True)
# Out:
# C:\Users\AL REHMAN LAPTOPS\AppData\Local\Temp\ipykernel_10560\2497516923.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Language'].fillna(df['Language'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# Students         0
# Marks            0
# Language         0
# Age              0
# Gender           0
# City             1
# Country          0
# Passed           0
# Grade            0
# Attendance       0
# Project_Score    0
# Assignments      0
# Quizzes          0
# Semester         0
# GPA              0
# Scholarship      0
# Phone            0
# Email            2
# Join_Year        0
# Graduated        0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Students         0
# Marks            0
# Language         0
# Age              0
# Gender           0
# City             0
# Country          0
# Passed           0
# Grade            0
# Attendance       0
# Project_Score    0
# Assignments      0
# Quizzes          0
# Semester         0
# GPA              0
# Scholarship      0
# Phone            0
# Email            0
# Join_Year        0
# Graduated        0
# dtype: int64

# %%
df.head()
# Out:
#   Students  Marks    Language   Age Gender      City   Country  Passed Grade  \
# 0      Ali   85.0      Python  21.0   Male    Lahore  Pakistan    True     B
# 1   Hassam   76.0  JavaScript  23.0   Male   Karachi  Pakistan    True     A
# 3   Waseem   92.0           C  20.0   Male    Multan  Pakistan    True     D
# 4   Sattar   67.0          C#  25.0   Male  Peshawar  Pakistan   False     D
# 5    Noman   73.0        Java  24.0   Male    Quetta  Pakistan   False     A
#
#    Attendance  Project_Score  Assignments  Quizzes Semester   GPA  \
# 0          98             68           10        9   Spring  2.96
# 1          89             78            5        3     Fall  2.20
# 3          75             83           12        9   Spring  3.44
# 4          89             75            6        3   Spring  3.25
# 5          72             82            7        5   Spring  2.41
#
#    Scholarship            Phone                 Email  Join_Year  Graduated
# 0        False  +92-300-3759168  student1@example.com       2021      False
# 1         True  +92-300-1887373  student2@example.com       2021      False
# 3         True  +92-300-4587653  student4@example.com       2024      False
# 4         True  +92-300-1584231  student5@example.com       2024      False
# 5        False  +92-300-7222931  student6@example.com       2022       True

# %%
df['Students'].apply(lambda y: y)
# Out:
# 0        Ali
# 1     Hassam
# 3     Waseem
# 4     Sattar
# 5      Noman
# 7     Ayesha
# 8      Bilal
# 9       Zain
# 10    Hassan
# 11      Sara
# 12     Hamza
# 13      Iqra
# 14     Usman
# 15    Fatima
# 16     Ahmed
# 17     Tariq
# 18      Maha
# 19      Raza
# 20       Ali
# 21      Hina
# Name: Students, dtype: object

# %%
df['Email'].apply(lambda x: x.replace('student', df['Students'].apply(lambda y: y)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df['Email'].apply(lambda x: x.replace('student', df['Students'].apply(lambda y: y)))
#
# File c:\Users\AL REHMAN LAPTOPS\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:4935, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4800 def apply(
#    4801     self,
#    4802     func: AggFuncType,
#    (...)   4807     **kwargs,
#    4808 ) -> DataFrame | Series:
#    4809     """
#    4810     Invoke function on values of Series.
#    4811
#    (...)   4926     dtype: float64
#    4927     """
#    4928     return SeriesApply(
#    4929         self,
#    4930         func,
#    4931         convert_dtype=convert_dtype,
#    4932         by_row=by_row,
#    4933         args=args,
#    4934         kwargs=kwargs,
# -> 4935     ).apply()
#
# File c:\Users\AL REHMAN LAPTOPS\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\apply.py:1422, in SeriesApply.apply(self)
#    1419     return self.apply_compat()
#    1421 # self.func is Callable
# -> 1422 return self.apply_standard()
#
# File c:\Users\AL REHMAN LAPTOPS\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\apply.py:1502, in SeriesApply.apply_standard(self)
#    1496 # row-wise access
#    1497 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1498 # we need to give `na_action="ignore"` for categorical data.
#    1499 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1500 #  Categorical (GH51645).
#    1501 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1502 mapped = obj._map_values(
#    1503     mapper=curried, na_action=action, convert=self.convert_dtype
#    1504 )
#    1506 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1507     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1508     #  See also GH#25959 regarding EA support
#    1509     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\AL REHMAN LAPTOPS\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\base.py:925, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     922 if isinstance(arr, ExtensionArray):
#     923     return arr.map(mapper, na_action=na_action)
# --> 925 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\AL REHMAN LAPTOPS\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File pandas/_libs/lib.pyx:2999, in pandas._libs.lib.map_infer()
#
# Cell In[24], line 1, in <lambda>(x)
# ----> 1 df['Email'].apply(lambda x: x.replace('student', df['Students'].apply(lambda y: y)))
#
# TypeError: replace() argument 2 must be str, not Series

# %%
df['Email'] = df['Students'].str.lower() + '@' + df['Email'].str.split('@')[1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8412\2171440529.py in <module>
# ----> 1 df['Email'] = df['Students'].str.lower() + '@' + df['Email'].str.split('@')[1]
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      68         other = item_from_zerodim(other)
#      69
# ---> 70         return method(self, other)
#      71
#      72     return new_method
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arraylike.py in __add__(self, other)
#      98     @unpack_zerodim_and_defer("__add__")
#      99     def __add__(self, other):
# --> 100         return self._arith_method(other, operator.add)
#     101
#     102     @unpack_zerodim_and_defer("__radd__")
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in _arith_method(self, other, op)
#    5637     def _arith_method(self, other, op):
#    5638         self, other = ops.align_method_SERIES(self, other)
# -> 5639         return base.IndexOpsMixin._arith_method(self, other, op)
#    5640
#    5641
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\base.py in _arith_method(self, other, op)
#    1293
#    1294         with np.errstate(all="ignore"):
# -> 1295             result = ops.arithmetic_op(lvalues, rvalues, op)
#    1296
#    1297         return self._construct_result(result, name=res_name)
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in arithmetic_op(left, right, op)
#     220         _bool_arith_check(op, left, right)
#     221
# --> 222         res_values = _na_arithmetic_op(left, right, op)
#     223
#     224     return res_values
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     161
#     162     try:
# --> 163         result = func(left, right)
#     164     except TypeError:
#     165         if not is_cmp and (is_object_dtype(left.dtype) or is_object_dtype(right)):
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     237         if use_numexpr:
#     238             # error: "None" not callable
# --> 239             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240     return _evaluate_standard(op, op_str, a, b)
#     241
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     126
#     127     if result is None:
# --> 128         result = _evaluate_standard(op, op_str, a, b)
#     129
#     130     return result
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
#      67     if _TEST_MODE:
#      68         _store_test_result(False)
# ---> 69     return op(a, b)
#      70
#      71
#
# ValueError: operands could not be broadcast together with shapes (20,) (2,)

# %%
for element in df:
    # print(element)
    element['Email'].apply(lambda x: x.replace('student', element['Students']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8412\3571302821.py in <module>
#       1 for element in df:
#       2     # print(element)
# ----> 3     element['Email'].apply(lambda x: x.replace('student', element['Students']))
#
# TypeError: string indices must be integers

# %%
# for name, age, city in zip(names, ages, cities):
new_email = []
for name, email in zip(df['Students'], df['Email']):
    new_email.append(email.replace('student', name.lower()))
df['Email'] = new_email

# %%
df['Email']
# Out:
# 0         ali1@example.com
# 1      hassam2@example.com
# 3      waseem4@example.com
# 4      sattar5@example.com
# 5       noman6@example.com
# 7      ayesha8@example.com
# 8       bilal9@example.com
# 9       zain10@example.com
# 10    hassan11@example.com
# 11      sara12@example.com
# 12     hamza13@example.com
# 13      iqra14@example.com
# 14     usman15@example.com
# 15    fatima16@example.com
# 16     ahmed17@example.com
# 17     tariq18@example.com
# 18      maha19@example.com
# 19      raza20@example.com
# 20        ali1@example.com
# 21       hina7@example.com
# Name: Email, dtype: object

# %%
df.head()
# Out:
#   Students  Marks    Language   Age Gender      City   Country  Passed Grade  \
# 0      Ali   85.0      Python  21.0   Male    Lahore  Pakistan    True     B
# 1   Hassam   76.0  JavaScript  23.0   Male   Karachi  Pakistan    True     A
# 3   Waseem   92.0           C  20.0   Male    Multan  Pakistan    True     D
# 4   Sattar   67.0          C#  25.0   Male  Peshawar  Pakistan   False     D
# 5    Noman   73.0        Java  24.0   Male    Quetta  Pakistan   False     A
#
#    Attendance  Project_Score  Assignments  Quizzes Semester   GPA  \
# 0          98             68           10        9   Spring  2.96
# 1          89             78            5        3     Fall  2.20
# 3          75             83           12        9   Spring  3.44
# 4          89             75            6        3   Spring  3.25
# 5          72             82            7        5   Spring  2.41
#
#    Scholarship            Phone                Email  Join_Year  Graduated
# 0        False  +92-300-3759168     ali1@example.com       2021      False
# 1         True  +92-300-1887373  hassam2@example.com       2021      False
# 3         True  +92-300-4587653  waseem4@example.com       2024      False
# 4         True  +92-300-1584231  sattar5@example.com       2024      False
# 5        False  +92-300-7222931   noman6@example.com       2022       True
